# %% [markdown]
# # Actividad 4.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('listings - New York_noNulls.csv')
# Quitamos el Unamed: 0
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 1                     6848                 https://www.airbnb.com/rooms/6848
# 2                     6872                 https://www.airbnb.com/rooms/6872
# 3                     6990                 https://www.airbnb.com/rooms/6990
# 4                     7064                 https://www.airbnb.com/rooms/7064
# ...                    ...                                               ...
# 37543  1281096465598617765  https://www.airbnb.com/rooms/1281096465598617765
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
# 37546  1281431427554747842  https://www.airbnb.com/rooms/1281431427554747842
# 37547  1281465359952960262  https://www.airbnb.com/rooms/1281465359952960262
#
#             scrape_id last_scraped           source  \
# 0      20241104040953   2024-11-04      city scrape
# 1      20241104040953   2024-11-04      city scrape
# 2      20241104040953   2024-11-04      city scrape
# 3      20241104040953   2024-11-04      city scrape
# 4      20241104040953   2024-11-04  previous scrape
# ...               ...          ...              ...
# 37543  20241104040953   2024-11-04      city scrape
# 37544  20241104040953   2024-11-04      city scrape
# 37545  20241104040953   2024-11-04      city scrape
# 37546  20241104040953   2024-11-04      city scrape
# 37547  20241104040953   2024-11-04      city scrape
#
#                                                     name  \
# 0                        Skylit Midtown Castle Sanctuary
# 1                       Only 2 stops to Manhattan studio
# 2      Uptown Sanctuary w/ Private Bath (Month to Month)
# 3                                UES Beautiful Blue Room
# 4      Amazing location! Wburg. Large, bright & tranquil
# ...                                                  ...
# 37543  Furnished room in Bensonhurst, only for girls #23
# 37544                    Luxury Reno'd Designer Townhome
# 37545                        Modern new 1 bed w/ rooftop
# 37546                          Beautiful 1 Bedroom Condo
# 37547                                   1200-2F MedRoom1
#
#                                              description  \
# 0      Beautiful, spacious skylit studio in the heart...
# 1      Comfortable studio apartment with super comfor...
# 2      This charming distancing-friendly month-to-mon...
# 3                        Beautiful peaceful healthy home
# 4      Large, private loft-like room in a spacious 2-...
# ...                                                  ...
# 37543  New room in Bensonhurst, living room has balco...
# 37544  Luxury gut renovated 3BR/2.5BA townhome on one...
# 37545  This stylish place is perfect for a person or ...
# 37546   Kick back and relax in this calm, stylish space.
# 37547  Enjoy a stylish experience at this centrally-l...
#
#                                    neighborhood_overview  \
# 0      Centrally located in the heart of Manhattan ju...
# 1                               No neighborhood_overview
# 2      This sweet Harlem sanctuary is a 10-20 minute ...
# 3      Location: Five minutes to Central Park, Museum...
# 4      - One stop from the East Village, Lower East S...
# ...                                                  ...
# 37543                           No neighborhood_overview
# 37544                           No neighborhood_overview
# 37545                           No neighborhood_overview
# 37546                           No neighborhood_overview
# 37547                           No neighborhood_overview
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...       2845  ...
# 1      https://a0.muscache.com/pictures/e4f031a7-f146...      15991  ...
# 2      https://a0.muscache.com/pictures/miso/Hosting-...      16104  ...
# 3      https://a0.muscache.com/pictures/be6cd5b3-9295...      16800  ...
# 4      https://a0.muscache.com/pictures/13708959/7e74...      17297  ...
# ...                                                  ...        ...  ...
# 37543  https://a0.muscache.com/pictures/miso/Hosting-...    3223938  ...
# 37544  https://a0.muscache.com/pictures/miso/Hosting-...   43042852  ...
# 37545  https://a0.muscache.com/pictures/miso/Hosting-...   23297442  ...
# 37546  https://a0.muscache.com/pictures/hosting/Hosti...  530889967  ...
# 37547  https://a0.muscache.com/pictures/hosting/Hosti...  267272502  ...
#
#       review_scores_checkin review_scores_communication  \
# 0                      4.77                        4.80
# 1                      4.85                        4.80
# 2                      5.00                        5.00
# 3                      4.96                        4.95
# 4                      5.00                        5.00
# ...                     ...                         ...
# 37543                  0.00                        0.00
# 37544                  0.00                        0.00
# 37545                  0.00                        0.00
# 37546                  0.00                        0.00
# 37547                  0.00                        0.00
#
#       review_scores_location review_scores_value instant_bookable  \
# 0                       4.81                4.40                f
# 1                       4.69                4.58                f
# 2                       5.00                5.00                f
# 3                       4.85                4.85                f
# 4                       5.00                5.00                f
# ...                      ...                 ...              ...
# 37543                   0.00                0.00                f
# 37544                   0.00                0.00                f
# 37545                   0.00                0.00                t
# 37546                   0.00                0.00                f
# 37547                   0.00                0.00                f
#
#       calculated_host_listings_count  \
# 0                                  3
# 1                                  1
# 2                                  2
# 3                                  1
# 4                                  2
# ...                              ...
# 37543                            740
# 37544                              1
# 37545                              1
# 37546                              1
# 37547                             19
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               3
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 37543                                           0
# 37544                                           1
# 37545                                           1
# 37546                                           1
# 37547                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                2
# 3                                                1
# 4                                                2
# ...                                            ...
# 37543                                          740
# 37544                                            0
# 37545                                            0
# 37546                                            0
# 37547                                           18
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.27
# 1                                               0              1.04
# 2                                               0              0.03
# 3                                               0              1.37
# 4                                               0              0.08
# ...                                           ...               ...
# 37543                                           0              1.00
# 37544                                           0              1.00
# 37545                                           0              1.00
# 37546                                           0              1.00
# 37547                                           0              1.00
#
# [37548 rows x 73 columns]

# %%
# Delimitamos las columnas que seleccionaremos
df = df[['id', 'source', 'name', 'description', 'neighborhood_overview',
       'host_id', 'host_name', 'host_since', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
       'host_verifications', 'host_identity_verified',
       'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
       'room_type', 'accommodates', 'bathrooms_text', 'bedrooms', 'beds',
       'amenities', 'price', 'minimum_nights', 'maximum_nights',
       'has_availability', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable', 'reviews_per_month']]
df
# Out:
#                         id           source  \
# 0                     2595      city scrape
# 1                     6848      city scrape
# 2                     6872      city scrape
# 3                     6990      city scrape
# 4                     7064  previous scrape
# ...                    ...              ...
# 37543  1281096465598617765      city scrape
# 37544  1281230979116575465      city scrape
# 37545  1281263542832791722      city scrape
# 37546  1281431427554747842      city scrape
# 37547  1281465359952960262      city scrape
#
#                                                     name  \
# 0                        Skylit Midtown Castle Sanctuary
# 1                       Only 2 stops to Manhattan studio
# 2      Uptown Sanctuary w/ Private Bath (Month to Month)
# 3                                UES Beautiful Blue Room
# 4      Amazing location! Wburg. Large, bright & tranquil
# ...                                                  ...
# 37543  Furnished room in Bensonhurst, only for girls #23
# 37544                    Luxury Reno'd Designer Townhome
# 37545                        Modern new 1 bed w/ rooftop
# 37546                          Beautiful 1 Bedroom Condo
# 37547                                   1200-2F MedRoom1
#
#                                              description  \
# 0      Beautiful, spacious skylit studio in the heart...
# 1      Comfortable studio apartment with super comfor...
# 2      This charming distancing-friendly month-to-mon...
# 3                        Beautiful peaceful healthy home
# 4      Large, private loft-like room in a spacious 2-...
# ...                                                  ...
# 37543  New room in Bensonhurst, living room has balco...
# 37544  Luxury gut renovated 3BR/2.5BA townhome on one...
# 37545  This stylish place is perfect for a person or ...
# 37546   Kick back and relax in this calm, stylish space.
# 37547  Enjoy a stylish experience at this centrally-l...
#
#                                    neighborhood_overview    host_id  \
# 0      Centrally located in the heart of Manhattan ju...       2845
# 1                               No neighborhood_overview      15991
# 2      This sweet Harlem sanctuary is a 10-20 minute ...      16104
# 3      Location: Five minutes to Central Park, Museum...      16800
# 4      - One stop from the East Village, Lower East S...      17297
# ...                                                  ...        ...
# 37543                           No neighborhood_overview    3223938
# 37544                           No neighborhood_overview   43042852
# 37545                           No neighborhood_overview   23297442
# 37546                           No neighborhood_overview  530889967
# 37547                           No neighborhood_overview  267272502
#
#            host_name  host_since     host_location  \
# 0           Jennifer  2008-09-09     Woodstock, NY
# 1      Allen & Irina  2009-05-06      New York, NY
# 2                Kae  2009-05-07      New York, NY
# 3                Cyn  2009-05-12      New York, NY
# 4             Joelle  2009-05-15      New York, NY
# ...              ...         ...               ...
# 37543         Eugene  2012-08-11      New York, NY
# 37544         Joshua  2015-08-31      New York, NY
# 37545          Amira  2014-11-03      New York, NY
# 37546          Maria  2023-08-09  No host_location
# 37547          Julio  2019-06-09      New York, NY
#
#                                               host_about  ... last_review  \
# 0      A New Yorker since 2000! My passion is creatin...  ...  2022-06-21
# 1      We love to travel. When we travel we like to s...  ...  2024-10-05
# 2      A former life in fashion and wellness has left...  ...  2022-06-05
# 3      Capturing the Steinbeck side of life in its Fi...  ...  2024-10-31
# 4      I have lived in the same apartment in Brooklyn...  ...  2022-09-12
# ...                                                  ...  ...         ...
# 37543  my number: (Phone number hidden by Airbnb) , m...  ...     No date
# 37544  We live in Brooklyn, and use this home as our ...  ...     No date
# 37545  I love being a New Yorker but designed a home ...  ...     No date
# 37546                                     No description  ...     No date
# 37547  Thank  you for visiting our listings. My name ...  ...     No date
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                     4.68                   4.73                      4.63
# 1                     4.58                   4.59                      4.85
# 2                     5.00                   5.00                      5.00
# 3                     4.88                   4.83                      4.95
# 4                     4.91                   5.00                      4.91
# ...                    ...                    ...                       ...
# 37543                 0.00                   0.00                      0.00
# 37544                 0.00                   0.00                      0.00
# 37545                 0.00                   0.00                      0.00
# 37546                 0.00                   0.00                      0.00
# 37547                 0.00                   0.00                      0.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.77                         4.80
# 1                       4.85                         4.80
# 2                       5.00                         5.00
# 3                       4.96                         4.95
# 4                       5.00                         5.00
# ...                      ...                          ...
# 37543                   0.00                         0.00
# 37544                   0.00                         0.00
# 37545                   0.00                         0.00
# 37546                   0.00                         0.00
# 37547                   0.00                         0.00
#
#       review_scores_location review_scores_value instant_bookable  \
# 0                       4.81                4.40                f
# 1                       4.69                4.58                f
# 2                       5.00                5.00                f
# 3                       4.85                4.85                f
# 4                       5.00                5.00                f
# ...                      ...                 ...              ...
# 37543                   0.00                0.00                f
# 37544                   0.00                0.00                f
# 37545                   0.00                0.00                t
# 37546                   0.00                0.00                f
# 37547                   0.00                0.00                f
#
#        reviews_per_month
# 0                   0.27
# 1                   1.04
# 2                   0.03
# 3                   1.37
# 4                   0.08
# ...                  ...
# 37543               1.00
# 37544               1.00
# 37545               1.00
# 37546               1.00
# 37547               1.00
#
# [37548 rows x 50 columns]

# %%
df.isnull().sum()
# Out:
# id                             0
# source                         0
# name                           0
# description                    0
# neighborhood_overview          0
# host_id                        0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_identity_verified         0
# neighbourhood_cleansed         0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# has_availability               0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# first_review                   0
# last_review                    0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# instant_bookable               0
# reviews_per_month              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37548 entries, 0 to 37547
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           37548 non-null  int64
#  1   source                       37548 non-null  object
#  2   name                         37548 non-null  object
#  3   description                  37548 non-null  object
#  4   neighborhood_overview        37548 non-null  object
#  5   host_id                      37548 non-null  int64
#  6   host_name                    37548 non-null  object
#  7   host_since                   37548 non-null  object
#  8   host_location                37548 non-null  object
#  9   host_about                   37548 non-null  object
#  10  host_response_time           37548 non-null  object
#  11  host_response_rate           37548 non-null  object
#  12  host_acceptance_rate         37548 non-null  object
#  13  host_is_superhost            37548 non-null  object
#  14  host_listings_count          37548 non-null  float64
#  15  host_total_listings_count    37548 non-null  float64
#  16  host_verifications           37548 non-null  object
#  17  host_identity_verified       37548 non-null  object
#  18  neighbourhood_cleansed       37548 non-null  object
#  19  latitude                     37548 non-null  float64
#  20  longitude                    37548 non-null  float64
#  21  property_type                37548 non-null  object
#  22  room_type                    37548 non-null  object
#  23  accommodates                 37548 non-null  int64
#  24  bathrooms_text               37548 non-null  object
#  25  bedrooms                     37548 non-null  float64
#  26  beds                         37548 non-null  float64
#  27  amenities                    37548 non-null  object
#  28  price                        37548 non-null  float64
#  29  minimum_nights               37548 non-null  int64
#  30  maximum_nights               37548 non-null  int64
#  31  has_availability             37548 non-null  object
#  32  availability_30              37548 non-null  int64
#  33  availability_60              37548 non-null  int64
#  34  availability_90              37548 non-null  int64
#  35  availability_365             37548 non-null  int64
#  36  number_of_reviews            37548 non-null  int64
#  37  number_of_reviews_ltm        37548 non-null  int64
#  38  number_of_reviews_l30d       37548 non-null  int64
#  39  first_review                 37548 non-null  object
#  40  last_review                  37548 non-null  object
#  41  review_scores_rating         37548 non-null  float64
#  42  review_scores_accuracy       37548 non-null  float64
#  43  review_scores_cleanliness    37548 non-null  float64
#  44  review_scores_checkin        37548 non-null  float64
#  45  review_scores_communication  37548 non-null  float64
#  46  review_scores_location       37548 non-null  float64
#  47  review_scores_value          37548 non-null  float64
#  48  instant_bookable             37548 non-null  object
#  49  reviews_per_month            37548 non-null  float64
# dtypes: float64(15), int64(12), object(23)
# memory usage: 14.3+ MB

# %%
# Dividimos el dataset en cualitatitvas y cuantitativas
cualitativas = df.select_dtypes(include=['object'])
cuantitativas = df.select_dtypes(include=['float64', 'int64'])
# Dado que los id y las coordenadas no son variables que nos interese analizar cuantitativamente, las quitamos de cuantitativas y lo pasamos a cualitativas
# Procuramos que estas variables estén al incio del dataset
cualitativas = pd.concat([df['id'], df['host_id'], cualitativas], axis=1)
cuantitativas = cuantitativas.drop(['id', 'host_id', 'latitude', 'longitude'], axis=1)

# %%
cualitativas.columns
# Out:
# Index(['id', 'host_id', 'source', 'name', 'description',
#        'neighborhood_overview', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood_cleansed', 'property_type',
#        'room_type', 'bathrooms_text', 'amenities', 'has_availability',
#        'first_review', 'last_review', 'instant_bookable'],
#       dtype='object')

# %%
cuantitativas.columns
# Out:
# Index(['host_listings_count', 'host_total_listings_count', 'accommodates',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
# Realizamos un diagrama de caja o bigote de cada columna del df
fig = plt.figure(figsize=(30, 30))
cuantitativas.plot(kind='box', vert=False)
plt.title('Valores atípicos de las variables cuantitativas')
plt.show()

# %% [markdown]
# ## Procedimiento "desviación estándar" para eliminar outliers en df

# %%
# Método aplicando la desviación estándar. Encuentro los valores extremos
# Se considera un valor extremo si está a más de 3 desviaciones estándar de la media
y = cuantitativas
limite_superior = y.mean() + 3 * y.std()
limite_inferior = y.mean() - 3 * y.std()
print("Límite superior permitido: ",limite_superior)
# Ponemos una línea separadora
print("----------------------------------------------------------------")
print("Límite inferior permitido: ", limite_inferior)
# Out:
# Límite superior permitido:  host_listings_count            2.739300e+03
# host_total_listings_count      3.463593e+03
# accommodates                   8.536390e+00
# bedrooms                       3.944916e+00
# beds                           4.330698e+00
# price                          1.228493e+03
# minimum_nights                 1.231369e+02
# maximum_nights                 3.330713e+07
# availability_30                4.563935e+01
# availability_60                9.488272e+01
# availability_90                1.477216e+02
# availability_365               5.952921e+02
# number_of_reviews              2.094637e+02
# number_of_reviews_ltm          5.764249e+01
# number_of_reviews_l30d         5.175663e+00
# review_scores_rating           9.902807e+00
# review_scores_accuracy         9.980794e+00
# review_scores_cleanliness      9.786339e+00
# review_scores_checkin          1.009998e+01
# review_scores_communication    1.009622e+01
# review_scores_location         9.918053e+00
# review_scores_value            9.750072e+00
# reviews_per_month              6.522449e+00
# dtype: float64
# ----------------------------------------------------------------
# Límite inferior permitido:  host_listings_count           -2.315663e+03
# host_total_listings_count     -2.871860e+03
# accommodates                  -3.016576e+00
# bedrooms                      -1.299555e+00
# beds                          -1.561443e+00
# price                         -8.129021e+02
# minimum_nights                -6.450209e+01
# maximum_nights                -3.319053e+07
# availability_30               -2.700113e+01
# availability_60               -5.108902e+01
# availability_90               -7.242195e+01
# availability_365              -2.778079e+02
# number_of_reviews             -1.584479e+02
# number_of_reviews_ltm         -5.055589e+01
# number_of_reviews_l30d        -4.526148e+00
# review_scores_rating          -3.368614e+00
# review_scores_accuracy        -3.394677e+00
# review_scores_cleanliness     -3.347629e+00
# review_scores_checkin         -3.418329e+00
# review_scores_communication   -3.422539e+00
# review_scores_location        -3.363530e+00
# review_scores_value           -3.335943e+00
# reviews_per_month             -4.570554e+00
# dtype: float64

# %%
# Obtenemos datos y los outliers se convierten en nulos en el df
df2 = cuantitativas[(y <= limite_superior) & (y >= limite_inferior)]
df2
# Out:
#        host_listings_count  host_total_listings_count  accommodates  bedrooms  \
# 0                      7.0                        9.0           1.0       0.0
# 1                      1.0                        1.0           3.0       2.0
# 2                      2.0                        2.0           1.0       1.0
# 3                      1.0                        6.0           1.0       1.0
# 4                      2.0                        2.0           2.0       1.0
# ...                    ...                        ...           ...       ...
# 37543                742.0                     1438.0           1.0       NaN
# 37544                  2.0                        2.0           6.0       3.0
# 37545                  1.0                        5.0           2.0       1.0
# 37546                  1.0                        2.0           3.0       1.0
# 37547                 26.0                       33.0           1.0       1.0
#
#        beds  price  minimum_nights  maximum_nights  availability_30  \
# 0       1.0  240.0            30.0          1125.0               30
# 1       1.0   83.0            30.0           120.0                0
# 2       1.0   65.0            30.0           180.0               23
# 3       1.0   71.0            30.0           365.0                0
# 4       1.0  138.0            30.0            45.0                0
# ...     ...    ...             ...             ...              ...
# 37543   1.0   28.0            30.0           365.0                1
# 37544   3.0  475.0            30.0           365.0                0
# 37545   1.0  162.0            30.0            93.0                3
# 37546   1.0  250.0            30.0           365.0               29
# 37547   1.0   52.0            30.0           365.0               29
#
#        availability_60  ...  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                   60  ...                    0.0                     0.0
# 1                   15  ...                    4.0                     1.0
# 2                   53  ...                    0.0                     0.0
# 3                   23  ...                    4.0                     1.0
# 4                    0  ...                    0.0                     0.0
# ...                ...  ...                    ...                     ...
# 37543               31  ...                    0.0                     0.0
# 37544                0  ...                    0.0                     0.0
# 37545               33  ...                    0.0                     0.0
# 37546               59  ...                    0.0                     0.0
# 37547               59  ...                    0.0                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.68                    4.73
# 1                      4.58                    4.59
# 2                      5.00                    5.00
# 3                      4.88                    4.83
# 4                      4.91                    5.00
# ...                     ...                     ...
# 37543                  0.00                    0.00
# 37544                  0.00                    0.00
# 37545                  0.00                    0.00
# 37546                  0.00                    0.00
# 37547                  0.00                    0.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.63                   4.77
# 1                           4.85                   4.85
# 2                           5.00                   5.00
# 3                           4.95                   4.96
# 4                           4.91                   5.00
# ...                          ...                    ...
# 37543                       0.00                   0.00
# 37544                       0.00                   0.00
# 37545                       0.00                   0.00
# 37546                       0.00                   0.00
# 37547                       0.00                   0.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.81
# 1                             4.80                    4.69
# 2                             5.00                    5.00
# 3                             4.95                    4.85
# 4                             5.00                    5.00
# ...                            ...                     ...
# 37543                         0.00                    0.00
# 37544                         0.00                    0.00
# 37545                         0.00                    0.00
# 37546                         0.00                    0.00
# 37547                         0.00                    0.00
#
#        review_scores_value  reviews_per_month
# 0                     4.40               0.27
# 1                     4.58               1.04
# 2                     5.00               0.03
# 3                     4.85               1.37
# 4                     5.00               0.08
# ...                    ...                ...
# 37543                 0.00               1.00
# 37544                 0.00               1.00
# 37545                 0.00               1.00
# 37546                 0.00               1.00
# 37547                 0.00               1.00
#
# [37548 rows x 23 columns]

# %%
df2.isnull().sum()
# Out:
# host_listings_count            1525
# host_total_listings_count      1524
# accommodates                    576
# bedrooms                       1228
# beds                            675
# price                           285
# minimum_nights                  267
# maximum_nights                    1
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews               793
# number_of_reviews_ltm           356
# number_of_reviews_l30d          393
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# reviews_per_month               319
# dtype: int64

# %%
# Reemplazamos los nulos del df con la media
dfC = df2.copy()
dfC.fillna(round(df2.mean(), 1), inplace=True)
dfC.isnull().sum()
# Out:
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
# Realizamos un diagrama de caja o bigote de cada columna del df
fig = plt.figure(figsize=(30, 30))
dfC.plot(kind='box', vert=False)
plt.title('Valores atípicos de las variables cuantitativas')
plt.show()

# %% [markdown]
# ## Procedimiento "cuantiles" para sustituir outliers en df

# %%
# Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = cuantitativas
percentil25 = y.quantile(0.25) # Q1
percentil75 = y.quantile(0.75) # Q3
iqr = percentil75 - percentil25

limite_superior_iqr = percentil75 + 1.5 * iqr
limite_inferior_iqr = percentil25 - 1.5 * iqr
print("Límite superior permitido: ",limite_superior)
# Ponemos una línea separadora
print("----------------------------------------------------------------")
print("Límite inferior permitido: ",limite_inferior)
# Out:
# Límite superior permitido:  host_listings_count            2.739300e+03
# host_total_listings_count      3.463593e+03
# accommodates                   8.536390e+00
# bedrooms                       3.944916e+00
# beds                           4.330698e+00
# price                          1.228493e+03
# minimum_nights                 1.231369e+02
# maximum_nights                 3.330713e+07
# availability_30                4.563935e+01
# availability_60                9.488272e+01
# availability_90                1.477216e+02
# availability_365               5.952921e+02
# number_of_reviews              2.094637e+02
# number_of_reviews_ltm          5.764249e+01
# number_of_reviews_l30d         5.175663e+00
# review_scores_rating           9.902807e+00
# review_scores_accuracy         9.980794e+00
# review_scores_cleanliness      9.786339e+00
# review_scores_checkin          1.009998e+01
# review_scores_communication    1.009622e+01
# review_scores_location         9.918053e+00
# review_scores_value            9.750072e+00
# reviews_per_month              6.522449e+00
# dtype: float64
# ----------------------------------------------------------------
# Límite inferior permitido:  host_listings_count           -2.315663e+03
# host_total_listings_count     -2.871860e+03
# accommodates                  -3.016576e+00
# bedrooms                      -1.299555e+00
# beds                          -1.561443e+00
# price                         -8.129021e+02
# minimum_nights                -6.450209e+01
# maximum_nights                -3.319053e+07
# availability_30               -2.700113e+01
# availability_60               -5.108902e+01
# availability_90               -7.242195e+01
# availability_365              -2.778079e+02
# number_of_reviews             -1.584479e+02
# number_of_reviews_ltm         -5.055589e+01
# number_of_reviews_l30d        -4.526148e+00
# review_scores_rating          -3.368614e+00
# review_scores_accuracy        -3.394677e+00
# review_scores_cleanliness     -3.347629e+00
# review_scores_checkin         -3.418329e+00
# review_scores_communication   -3.422539e+00
# review_scores_location        -3.363530e+00
# review_scores_value           -3.335943e+00
# reviews_per_month             -4.570554e+00
# dtype: float64

# %%
# Obtenemos datos y los outliers se convierten en nulos en el df
df3 = cuantitativas[(y <= limite_superior_iqr) & (y >= limite_inferior_iqr)]
df3.isnull().sum()
# Out:
# host_listings_count             7148
# host_total_listings_count       7053
# accommodates                    1178
# bedrooms                       11126
# beds                            9176
# price                           2559
# minimum_nights                  7611
# maximum_nights                     9
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews               4931
# number_of_reviews_ltm           6500
# number_of_reviews_l30d          4297
# review_scores_rating               0
# review_scores_accuracy             0
# review_scores_cleanliness          0
# review_scores_checkin              0
# review_scores_communication        0
# review_scores_location             0
# review_scores_value                0
# reviews_per_month               3167
# dtype: int64

# %%
# Reemplazamos los nulos del df con la media
df_iqr = df3.copy()
df_iqr.fillna(round(df3.mean(), 1), inplace=True)
df_iqr
# Out:
#        host_listings_count  host_total_listings_count  accommodates  bedrooms  \
# 0                      7.0                        9.0           1.0       1.0
# 1                      1.0                        1.0           3.0       1.0
# 2                      2.0                        2.0           1.0       1.0
# 3                      1.0                        6.0           1.0       1.0
# 4                      2.0                        2.0           2.0       1.0
# ...                    ...                        ...           ...       ...
# 37543                  3.0                        4.5           1.0       1.0
# 37544                  2.0                        2.0           6.0       1.0
# 37545                  1.0                        5.0           2.0       1.0
# 37546                  1.0                        2.0           3.0       1.0
# 37547                  3.0                       33.0           1.0       1.0
#
#        beds  price  minimum_nights  maximum_nights  availability_30  \
# 0       1.0  240.0            30.0          1125.0               30
# 1       1.0   83.0            30.0           120.0                0
# 2       1.0   65.0            30.0           180.0               23
# 3       1.0   71.0            30.0           365.0                0
# 4       1.0  138.0            30.0            45.0                0
# ...     ...    ...             ...             ...              ...
# 37543   1.0   28.0            30.0           365.0                1
# 37544   1.0  159.8            30.0           365.0                0
# 37545   1.0  162.0            30.0            93.0                3
# 37546   1.0  250.0            30.0           365.0               29
# 37547   1.0   52.0            30.0           365.0               29
#
#        availability_60  ...  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                   60  ...                    0.0                     0.0
# 1                   15  ...                    0.3                     0.0
# 2                   53  ...                    0.0                     0.0
# 3                   23  ...                    0.3                     0.0
# 4                    0  ...                    0.0                     0.0
# ...                ...  ...                    ...                     ...
# 37543               31  ...                    0.0                     0.0
# 37544                0  ...                    0.0                     0.0
# 37545               33  ...                    0.0                     0.0
# 37546               59  ...                    0.0                     0.0
# 37547               59  ...                    0.0                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.68                    4.73
# 1                      4.58                    4.59
# 2                      5.00                    5.00
# 3                      4.88                    4.83
# 4                      4.91                    5.00
# ...                     ...                     ...
# 37543                  0.00                    0.00
# 37544                  0.00                    0.00
# 37545                  0.00                    0.00
# 37546                  0.00                    0.00
# 37547                  0.00                    0.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.63                   4.77
# 1                           4.85                   4.85
# 2                           5.00                   5.00
# 3                           4.95                   4.96
# 4                           4.91                   5.00
# ...                          ...                    ...
# 37543                       0.00                   0.00
# 37544                       0.00                   0.00
# 37545                       0.00                   0.00
# 37546                       0.00                   0.00
# 37547                       0.00                   0.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.81
# 1                             4.80                    4.69
# 2                             5.00                    5.00
# 3                             4.95                    4.85
# 4                             5.00                    5.00
# ...                            ...                     ...
# 37543                         0.00                    0.00
# 37544                         0.00                    0.00
# 37545                         0.00                    0.00
# 37546                         0.00                    0.00
# 37547                         0.00                    0.00
#
#        review_scores_value  reviews_per_month
# 0                     4.40               0.27
# 1                     4.58               1.04
# 2                     5.00               0.03
# 3                     4.85               1.37
# 4                     5.00               0.08
# ...                    ...                ...
# 37543                 0.00               1.00
# 37544                 0.00               1.00
# 37545                 0.00               1.00
# 37546                 0.00               1.00
# 37547                 0.00               1.00
#
# [37548 rows x 23 columns]

# %%
fig = plt.figure(figsize=(30, 30))
df_iqr.plot(kind='box', vert=False)
plt.title('Valores atípicos de las variables cuantitativas')
plt.show()

# %%
# Unimos el df cuantitativo limpio con el df cualitativo
datos_limpio = pd.concat([cualitativas, df_iqr], axis=1)
datos_limpio.isnull().sum()
# Out:
# id                             0
# host_id                        0
# source                         0
# name                           0
# description                    0
# neighborhood_overview          0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_verifications             0
# host_identity_verified         0
# neighbourhood_cleansed         0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# has_availability               0
# first_review                   0
# last_review                    0
# instant_bookable               0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
# Pasamos a un excel
datos_limpio.to_csv('listings - New York_clean.csv')
